# %%
print("Hello World")
# Out:
# Hello World

# %%
import matplotlib.pyplot as plt
f = lambda x: x**2
y = [f(x) for x in range(-2,6)]
x = range(-2,6)
plt.plot(x,y)

# %%
print(10+10, 10-10, 10*10, 10**10, 10/5, 10//5, )
# Out:
# 20 0 100 10000000000 2.0 2

# %%
hello = 0
while hello < 10:
    hello += 1
    print("Hello World")
# Out:
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
